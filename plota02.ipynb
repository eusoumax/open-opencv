# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from colorama import init
from termcolor import colored
import cvUtis as utils
def mostraImagem(img):
    if img is not None:
        plt.figure(figsize=(20,10))
        plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    else:
        print('img é nula')

# %%
imagem01 = cv2.imread('wonderwork-space-msx-enegy.jpg')
mostraImagem(imagem01)

# %%
utils.mostraImagem('wonderwork-space-msx-enegy.jpg',escala=(10,5))

# %%
utils.mostraImagemComReconhecimentoFacialCascade('wonderwork-space-msx-enegy.jpg')

# %%
utils.mostraImagemComReconhecimentoFacialCascade('img/frame0004.jpg')

# %%
listaRostos = utils.listarRostosImagemCascade('img/frame0004.jpg')

# %%
utils.mostraImagem(listaRostos[0],escala=(5,2))

# %%
pattern = r'https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{2,256}\.[a-z]{2,6}\b([-a-zA-Z0-9@:%_\+.~#?&//=]*)'
import re
regex = re.compile(pattern)

# %%
umchemba01 = 'https://instagram.fqnv1-1.fna.fbcdn.net/vp/6579744e8293106ff7d3f74650a2fc3e/5D58F81E/t51.2885-15/sh0.08/e35/p640x640/50854114_382666809195801_5792591852174946727_n.jpg?_nc_ht=instagram.fqnv1-1.fna.fbcdn.net'

umchemba02 = 'https://instagram.fqnv1-1.fna.fbcdn.net/vp/8e0bf7fe6046cef817c35f4204ada1ae/5D6776D4/t51.2885-15/e35/41705515_327926961298610_8338125433094652131_n.jpg?_nc_ht=instagram.fqnv1-1.fna.fbcdn.net'

teste = 'localhost:8889/lab'

match = regex.match(umchemba02)

if match:
    print('ok')
# Out:
# ok

# %%
umchemba01
# Out:
# 'https://instagram.fqnv1-1.fna.fbcdn.net/vp/6579744e8293106ff7d3f74650a2fc3e/5D58F81E/t51.2885-15/sh0.08/e35/p640x640/50854114_382666809195801_5792591852174946727_n.jpg?_nc_ht=instagram.fqnv1-1.fna.fbcdn.net'

# %%
utils.mostraImagem(umchemba01)

# %%
utils.salvarImagemUrl(umchemba01,'.','umchemba01.jpg')

# %%
utils.mostraImagem('umchemba01.jpg')

# %%
brindaaspencer01 = 'https://instagram.fqnv1-1.fna.fbcdn.net/vp/1d69340a0175a96d5b30ef83658e89ff/5D9CF7E0/t51.2885-15/sh0.08/e35/p640x640/59797428_310116709917970_8330457807181936555_n.jpg?_nc_ht=instagram.fqnv1-1.fna.fbcdn.net'

# %%
lista = utils.listarRostosImagemCascade('umchemba01.jpg')
len(lista)
utils.mostraImagem(lista[0],escala=(5,2))

# %%
imagemDesktop = utils.imagemTelaDesktop()
utils.mostraImagem(imagemDesktop)

# %%
lista02 = utils.listarRostosImagemCascade(imagemDesktop)
print('foram encontrado(s) {} rostos '.format(len(lista02)))
# Out:
# foram encontrado(s) 1 rostos

# %%
utils.mostrarRostosImagem(imagemDesktop,colunas=3)

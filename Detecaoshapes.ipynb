# %%
import cv2
import numpy as np
font = cv2.FONT_HERSHEY_COMPLEX
import cvUtis as utils

# %%
#utils.salvarImagemTelaDesktop('.','shapes.jpg')

# %%
utils.mostraImagem('shape0001.jpg')

# %%
#utils.salvarImagemTelaDesktop('.','tela_gata_azul03.jpg')

# %%
utils.mostraImagem('tela_gata_azul03.jpg')

# %%
utils.mostrarContornosImagem('shape0001.jpg')

# %%
#cv2.imshow("shapes", img)
#cv2.imshow("Threshold", threshold)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
